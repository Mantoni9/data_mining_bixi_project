# %% [markdown]
# # Model Template

# %%
# import necessary packages

import pandas as pd
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from xgboost import XGBRegressor
# Out:
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
# read data

train_df = pd.read_csv('data/preprocessed_data/train.csv')
val_df = pd.read_csv('data/preprocessed_data/validation.csv')
test_df = pd.read_csv('data/preprocessed_data/test.csv')
corona_df = pd.read_csv('data/preprocessed_data/corona.csv')

# %%
# split data

X_train = train_df.drop(columns='count')
y_train = train_df['count']

X_val = val_df.drop(columns='count')
y_val = val_df['count']

X_test = test_df.drop(columns='count')
y_test = test_df['count']

X_corona = corona_df.drop(columns='count')
y_corona = corona_df['count']

# %%
# hyperparameter tuning

try:
    hyperparameters_df = pd.read_csv('data/hyperparameter_tuning/xgboost.csv')
    
except FileNotFoundError:
    
    # df containing hyperparameters and evaluation metrics of each run
    hyperparameters_df = pd.DataFrame()
    
    # this function is used by optuna to tune the hyperparameters
    def objective(trial):
        # define hyperparameters
        colsample_bynode = trial.suggest_float('colsample_bynode', 0.01, 1)
        max_depth = trial.suggest_int('max_depth', 1, 10)
        subsample = trial.suggest_float('subsample', 0.01, 1)
        n_estimators = trial.suggest_int('n_estimators', 1, 200)
        gamma = trial.suggest_float('gamma', 0.0, 20.0)
        learning_rate = trial.suggest_float('learning_rate', 0.01, 1)
        
        # setup and train model
        xgb_reg = XGBRegressor(
            colsample_bynode=colsample_bynode,            
            max_depth=max_depth,
            subsample=subsample,
            n_estimators=n_estimators,
            gamma=gamma,
            learning_rate=learning_rate,
        )
        xgb_reg.fit(X_train, y_train)
        
        # make predictions
        y_val_pred = xgb_reg.predict(X_val)
        
        # evaluate predictions
        r_squared = r2_score(y_val, y_val_pred)
        rmse = mean_squared_error(y_val, y_val_pred) ** 0.5
        
        # insert results in dataframe
        global hyperparameters_df
        hyperparameters_df = hyperparameters_df.append(
            {'colsample_bynode': colsample_bynode,
             'max_depth': max_depth,
             'subsample': subsample,
             'n_estimators': n_estimators,
             'gamma': gamma,
             'learning_rate': learning_rate,
             'r_squared': r_squared,
             'rmse': rmse},
            ignore_index=True
        )
        
        # return rmse -> optuna will optimize rmse
        return rmse
        
        
    study = optuna.create_study()
    # start optimization
    study.optimize(objective, n_trials=25)
    
    # convert to correct data types
    hyperparameters_df[['n_estimators', 'max_depth']] = hyperparameters_df[['n_estimators', 'max_depth']].astype('int')
    
    # sort hyperparameter tuning results and save file
    hyperparameters_df = hyperparameters_df.sort_values('rmse', ascending=True)
    hyperparameters_df = hyperparameters_df.reset_index(drop=True)
    hyperparameters_df.to_csv('data/hyperparameter_tuning/xgboost.csv', index=False)
# Out:
# [I 2022-12-02 16:52:42,098] A new study created in memory with name: no-name-349939d7-288c-4c7e-9491-4fa92306d59f
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 16:52:44,803] Trial 0 finished with value: 20.174821647496323 and parameters: {'colsample_bynode': 0.7868170534135648, 'max_depth': 4, 'subsample': 0.5810115307370967, 'n_estimators': 6, 'gamma': 7.422409918349329, 'learning_rate': 0.3990675546102253}. Best is trial 0 with value: 20.174821647496323.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 16:52:52,488] Trial 1 finished with value: 19.61215565885372 and parameters: {'colsample_bynode': 0.24109849244152065, 'max_depth': 2, 'subsample': 0.06572468505129272, 'n_estimators': 103, 'gamma': 11.964609075650905, 'learning_rate': 0.3763460548938589}. Best is trial 1 with value: 19.61215565885372.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 16:53:08,435] Trial 2 finished with value: 23.93920008950646 and parameters: {'colsample_bynode': 0.44793820105848553, 'max_depth': 8, 'subsample': 0.03290896361649913, 'n_estimators': 66, 'gamma': 17.304280094310855, 'learning_rate': 0.6875680015419164}. Best is trial 1 with value: 19.61215565885372.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 16:53:38,405] Trial 3 finished with value: 15.096295749967215 and parameters: {'colsample_bynode': 0.9484402049815662, 'max_depth': 7, 'subsample': 0.634170222858679, 'n_estimators': 71, 'gamma': 16.350084961591516, 'learning_rate': 0.10370217538569036}. Best is trial 3 with value: 15.096295749967215.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 16:53:45,936] Trial 4 finished with value: 21.03434030011386 and parameters: {'colsample_bynode': 0.31174135512230366, 'max_depth': 1, 'subsample': 0.4484563636046105, 'n_estimators': 111, 'gamma': 0.4467594534402908, 'learning_rate': 0.43637260172942216}. Best is trial 3 with value: 15.096295749967215.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 16:54:10,429] Trial 5 finished with value: 15.560964634658916 and parameters: {'colsample_bynode': 0.4789721758966376, 'max_depth': 10, 'subsample': 0.8662576244594303, 'n_estimators': 62, 'gamma': 10.075789733325841, 'learning_rate': 0.8876926149457379}. Best is trial 3 with value: 15.096295749967215.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 16:54:25,105] Trial 6 finished with value: 14.992812185999123 and parameters: {'colsample_bynode': 0.8027292031216693, 'max_depth': 6, 'subsample': 0.45735933565919257, 'n_estimators': 42, 'gamma': 5.118422655415853, 'learning_rate': 0.2999932517910833}. Best is trial 6 with value: 14.992812185999123.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 16:55:25,864] Trial 7 finished with value: 12.6908865169848 and parameters: {'colsample_bynode': 0.4374757013068879, 'max_depth': 9, 'subsample': 0.8733759335991103, 'n_estimators': 194, 'gamma': 17.07041514477463, 'learning_rate': 0.3050386161708343}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 16:55:35,677] Trial 8 finished with value: 16.286571086872677 and parameters: {'colsample_bynode': 0.027023030957157246, 'max_depth': 7, 'subsample': 0.1822613961123251, 'n_estimators': 65, 'gamma': 2.074330673076652, 'learning_rate': 0.690932343304797}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 16:55:47,627] Trial 9 finished with value: 15.163914145829088 and parameters: {'colsample_bynode': 0.5029841238690946, 'max_depth': 6, 'subsample': 0.4642374249448245, 'n_estimators': 44, 'gamma': 7.218297134652454, 'learning_rate': 0.295908381230096}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 16:57:25,785] Trial 10 finished with value: 13.356954943086853 and parameters: {'colsample_bynode': 0.6995425654101133, 'max_depth': 10, 'subsample': 0.9977893234389568, 'n_estimators': 197, 'gamma': 19.22019234775421, 'learning_rate': 0.030028898156950923}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 16:59:02,613] Trial 11 finished with value: 13.015238395126914 and parameters: {'colsample_bynode': 0.6699362825139831, 'max_depth': 10, 'subsample': 0.9750589928784348, 'n_estimators': 200, 'gamma': 19.964824587515604, 'learning_rate': 0.042985654710925233}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 17:00:27,067] Trial 12 finished with value: 12.79240165522472 and parameters: {'colsample_bynode': 0.6561966394971104, 'max_depth': 9, 'subsample': 0.8643337353195419, 'n_estimators': 199, 'gamma': 14.695009031877575, 'learning_rate': 0.16540026958692494}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 17:01:09,716] Trial 13 finished with value: 12.845107939800062 and parameters: {'colsample_bynode': 0.2660172847657748, 'max_depth': 9, 'subsample': 0.7673873845488676, 'n_estimators': 158, 'gamma': 13.876090465535738, 'learning_rate': 0.20727477144778111}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 17:01:37,703] Trial 14 finished with value: 15.182455170052283 and parameters: {'colsample_bynode': 0.6291566816299368, 'max_depth': 4, 'subsample': 0.7579458241032857, 'n_estimators': 149, 'gamma': 14.208554561992944, 'learning_rate': 0.549822263559067}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 17:02:24,625] Trial 15 finished with value: 12.86848874296108 and parameters: {'colsample_bynode': 0.3825246187957007, 'max_depth': 8, 'subsample': 0.816738823851885, 'n_estimators': 170, 'gamma': 15.633954110842016, 'learning_rate': 0.18320166871410873}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 17:02:48,383] Trial 16 finished with value: 15.079495218432312 and parameters: {'colsample_bynode': 0.1488277498592021, 'max_depth': 8, 'subsample': 0.32615947570201664, 'n_estimators': 136, 'gamma': 11.85508275753535, 'learning_rate': 0.5486919182131484}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 17:03:31,123] Trial 17 finished with value: 15.038159983522252 and parameters: {'colsample_bynode': 0.9789885436402035, 'max_depth': 4, 'subsample': 0.6496300669697413, 'n_estimators': 176, 'gamma': 17.334154166401046, 'learning_rate': 0.2445284636499881}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 17:04:22,324] Trial 18 finished with value: 16.100306033561147 and parameters: {'colsample_bynode': 0.5879639018181901, 'max_depth': 9, 'subsample': 0.9050021767519917, 'n_estimators': 127, 'gamma': 13.304936033288964, 'learning_rate': 0.9982384733528742}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 17:06:14,604] Trial 19 finished with value: 12.944731356772797 and parameters: {'colsample_bynode': 0.8428802776107439, 'max_depth': 9, 'subsample': 0.7114436122115217, 'n_estimators': 181, 'gamma': 18.129389597404096, 'learning_rate': 0.12006579271067686}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 17:06:55,463] Trial 20 finished with value: 14.34301008116997 and parameters: {'colsample_bynode': 0.570749857890869, 'max_depth': 5, 'subsample': 0.9090581965591832, 'n_estimators': 152, 'gamma': 15.217845457093091, 'learning_rate': 0.6612507906550324}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 17:07:38,489] Trial 21 finished with value: 12.963625650708368 and parameters: {'colsample_bynode': 0.2140253187729213, 'max_depth': 9, 'subsample': 0.7921709807944333, 'n_estimators': 164, 'gamma': 13.216584152547178, 'learning_rate': 0.1969758475698104}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 17:08:32,258] Trial 22 finished with value: 13.283931414648363 and parameters: {'colsample_bynode': 0.4008212997712595, 'max_depth': 7, 'subsample': 0.7110653452263918, 'n_estimators': 189, 'gamma': 10.268820933587499, 'learning_rate': 0.31332248528278095}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 17:09:01,903] Trial 23 finished with value: 15.06792836713477 and parameters: {'colsample_bynode': 0.09478874997999603, 'max_depth': 9, 'subsample': 0.847341471423482, 'n_estimators': 164, 'gamma': 15.145139520833219, 'learning_rate': 0.145580940584548}. Best is trial 7 with value: 12.6908865169848.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_4936/2964968325.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-12-02 17:09:48,864] Trial 24 finished with value: 13.393038648052945 and parameters: {'colsample_bynode': 0.32179163237028624, 'max_depth': 8, 'subsample': 0.9275639469479694, 'n_estimators': 184, 'gamma': 11.986283869941442, 'learning_rate': 0.45950704246148805}. Best is trial 7 with value: 12.6908865169848.

# %%
hyperparameters_df.head()
# Out:
#    colsample_bynode  max_depth  subsample  n_estimators      gamma  \
# 0          0.437476          9   0.873376           194  17.070415
# 1          0.656197          9   0.864334           199  14.695009
# 2          0.266017          9   0.767387           158  13.876090
# 3          0.382525          8   0.816739           170  15.633954
# 4          0.842880          9   0.711444           181  18.129390
#
#    learning_rate  r_squared       rmse
# 0       0.305039   0.766170  12.690887
# 1       0.165400   0.762414  12.792402
# 2       0.207275   0.760452  12.845108
# 3       0.183202   0.759579  12.868489
# 4       0.120066   0.756722  12.944731

# %%
# build final model on test and validation data

X_final_train = pd.concat([X_train, X_val], ignore_index=True)
y_final_train = pd.concat([y_train, y_val], ignore_index=True)

# %%
# final model evaluation

# build and train model using the most successful hyperparameters
xgb_reg = XGBRegressor(
    colsample_bynode=hyperparameters_df.loc[0, 'colsample_bynode'],            
    max_depth=hyperparameters_df.loc[0, 'max_depth'],
    subsample=hyperparameters_df.loc[0, 'subsample'],
    n_estimators=hyperparameters_df.loc[0, 'n_estimators'],
    gamma=hyperparameters_df.loc[0, 'gamma'],
    learning_rate=hyperparameters_df.loc[0, 'learning_rate'],
)
xgb_reg.fit(X_final_train, y_final_train)

# make predictions
y_test_pred = xgb_reg.predict(X_test)

# evaluate predictions
r_squared = r2_score(y_test, y_test_pred)
rmse = mean_squared_error(y_test, y_test_pred) ** 0.5

print(f'R^2:\t{r_squared}')
print(f'RMSE:\t{rmse}')
# Out:
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# R^2:	0.7350558292809322
# RMSE:	13.688458311399897

# %%
# predictions on corona year 2020

# make predictions
y_corona_pred = xgb_reg.predict(X_corona)

# evaluate predictions
r_squared_c = r2_score(y_corona, y_corona_pred)
rmse_c = mean_squared_error(y_corona, y_corona_pred) ** 0.5

print(f'R^2:\t{r_squared_c}')
print(f'RMSE:\t{rmse_c}')
# Out:
# R^2:	-0.5426717375688861
# RMSE:	19.444180259435623
