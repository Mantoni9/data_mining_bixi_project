# %% [markdown]
# # Model Template

# %%
# import necessary packages

import pandas as pd
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from xgboost import XGBRegressor
# Out:
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
# read data

train_df = pd.read_csv('data/preprocessed_data/train.csv')
val_df = pd.read_csv('data/preprocessed_data/validation.csv')
test_df = pd.read_csv('data/preprocessed_data/test.csv')

# %%
# split data

X_train = train_df.drop(columns='count')
y_train = train_df['count']

X_val = val_df.drop(columns='count')
y_val = val_df['count']

X_test = test_df.drop(columns='count')
y_test = test_df['count']

# %%
# hyperparameter tuning

try:
    hyperparameters_df = pd.read_csv('data/hyperparameter_tuning/xgboost.csv')
    
except FileNotFoundError:
    
    # df containing hyperparameters and evaluation metrics of each run
    hyperparameters_df = pd.DataFrame()
    
    # this function is used by optuna to tune the hyperparameters
    def objective(trial):
        # define hyperparameters
        colsample_bynode = trial.suggest_int('colsample_bynode', 0.01, 1)
        max_depth = trial.suggest_int('max_depth', 1, 10)
        subsample = trial.suggest_float('subsample', 0.01, 1)
        n_estimators = trial.suggest_int('n_estimators', 1, 200)
        gamma = trial.suggest_float('gamma', 0.0, 20.0)
        learning_rate = trial.suggest_float('learning_rate', 0.01, 1)
        
        # setup and train model
        xgb_reg = XGBRegressor(
            colsample_bynode=colsample_bynode,            
            max_depth=max_depth,
            subsample=subsample,
            n_estimators=n_estimators,
            gamma=gamma,
            learning_rate=learning_rate,
        )
        xgb_reg.fit(X_train, y_train)
        
        # make predictions
        y_val_pred = xgb_reg.predict(X_val)
        
        # evaluate predictions
        r_squared = r2_score(y_val, y_val_pred)
        rmse = mean_squared_error(y_val, y_val_pred) ** 0.5
        
        # insert results in dataframe
        global hyperparameters_df
        hyperparameters_df = hyperparameters_df.append(
            {'colsample_bynode': colsample_bynode,
             'max_depth': max_depth,
             'subsample': subsample,
             'n_estimators': n_estimators,
             'gamma': gamma,
             'learning_rate': learning_rate,
             'r_squared': r_squared,
             'rmse': rmse},
            ignore_index=True
        )
        
        # return rmse -> optuna will optimize rmse
        return rmse
        
        
    study = optuna.create_study()
    # start optimization
    study.optimize(objective, n_trials=25)
    
    # convert to correct data types
    hyperparameters_df[['n_estimators', 'max_depth']] = hyperparameters_df[['n_estimators', 'max_depth']].astype('int')
    
    # sort hyperparameter tuning results and save file
    hyperparameters_df = hyperparameters_df.sort_values('rmse', ascending=True)
    hyperparameters_df = hyperparameters_df.reset_index(drop=True)
    hyperparameters_df.to_csv('data/hyperparameter_tuning/xgboost.csv', index=False)
# Out:
# [I 2022-11-17 11:42:05,925] A new study created in memory with name: no-name-6a76784f-f9ad-4eb3-882b-d51424e4b997
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:42:16,121] Trial 0 finished with value: 16.865554903998444 and parameters: {'colsample_bynode': 0, 'max_depth': 6, 'subsample': 0.23350782801764844, 'n_estimators': 92, 'gamma': 12.892708781040076, 'learning_rate': 0.874319913798563}. Best is trial 0 with value: 16.865554903998444.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:42:20,625] Trial 1 finished with value: 20.959888668729484 and parameters: {'colsample_bynode': 0, 'max_depth': 1, 'subsample': 0.30772546116742644, 'n_estimators': 72, 'gamma': 18.083413185843632, 'learning_rate': 0.7610463219799021}. Best is trial 0 with value: 16.865554903998444.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:42:31,074] Trial 2 finished with value: 17.68039028331807 and parameters: {'colsample_bynode': 1, 'max_depth': 5, 'subsample': 0.07379837316407545, 'n_estimators': 48, 'gamma': 3.8535194188559796, 'learning_rate': 0.09484086578819112}. Best is trial 0 with value: 16.865554903998444.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:42:43,351] Trial 3 finished with value: 18.679603593916795 and parameters: {'colsample_bynode': 0, 'max_depth': 4, 'subsample': 0.7655732766983623, 'n_estimators': 131, 'gamma': 9.746427969437384, 'learning_rate': 0.20490144523980314}. Best is trial 0 with value: 16.865554903998444.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:42:44,754] Trial 4 finished with value: 25.502321414740454 and parameters: {'colsample_bynode': 0, 'max_depth': 1, 'subsample': 0.7803334736324512, 'n_estimators': 7, 'gamma': 0.540111235180103, 'learning_rate': 0.6986579168681999}. Best is trial 0 with value: 16.865554903998444.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:43:18,063] Trial 5 finished with value: 14.460313671775216 and parameters: {'colsample_bynode': 1, 'max_depth': 5, 'subsample': 0.9192946213270772, 'n_estimators': 131, 'gamma': 4.22980648384824, 'learning_rate': 0.7649725274961301}. Best is trial 5 with value: 14.460313671775216.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:44:44,141] Trial 6 finished with value: 15.896665703528255 and parameters: {'colsample_bynode': 1, 'max_depth': 10, 'subsample': 0.08717603544265834, 'n_estimators': 190, 'gamma': 16.41658768173319, 'learning_rate': 0.38555683909343513}. Best is trial 5 with value: 14.460313671775216.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:45:04,874] Trial 7 finished with value: 15.77900324532468 and parameters: {'colsample_bynode': 0, 'max_depth': 10, 'subsample': 0.302360943205551, 'n_estimators': 154, 'gamma': 10.17662349629239, 'learning_rate': 0.6560247803519845}. Best is trial 5 with value: 14.460313671775216.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:45:33,630] Trial 8 finished with value: 21.073195773928017 and parameters: {'colsample_bynode': 1, 'max_depth': 6, 'subsample': 0.585842169193149, 'n_estimators': 77, 'gamma': 14.740576427164987, 'learning_rate': 0.01882376969966613}. Best is trial 5 with value: 14.460313671775216.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:45:43,895] Trial 9 finished with value: 20.74923520219504 and parameters: {'colsample_bynode': 0, 'max_depth': 1, 'subsample': 0.7141017056446091, 'n_estimators': 174, 'gamma': 14.37744152955229, 'learning_rate': 0.5894306865726214}. Best is trial 5 with value: 14.460313671775216.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:46:37,761] Trial 10 finished with value: 15.09998684214649 and parameters: {'colsample_bynode': 1, 'max_depth': 8, 'subsample': 0.9488908343760178, 'n_estimators': 124, 'gamma': 5.2368935744742915, 'learning_rate': 0.94800543229223}. Best is trial 5 with value: 14.460313671775216.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:47:33,286] Trial 11 finished with value: 14.891760507915963 and parameters: {'colsample_bynode': 1, 'max_depth': 8, 'subsample': 0.9625132157040159, 'n_estimators': 125, 'gamma': 5.813842226385982, 'learning_rate': 0.9924711321932979}. Best is trial 5 with value: 14.460313671775216.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:48:27,343] Trial 12 finished with value: 15.040628520390305 and parameters: {'colsample_bynode': 1, 'max_depth': 8, 'subsample': 0.9968603339787365, 'n_estimators': 123, 'gamma': 5.903126644926181, 'learning_rate': 0.9969903417809408}. Best is trial 5 with value: 14.460313671775216.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:48:53,138] Trial 13 finished with value: 15.611774818583834 and parameters: {'colsample_bynode': 1, 'max_depth': 3, 'subsample': 0.9024983190105469, 'n_estimators': 153, 'gamma': 0.9331813870482124, 'learning_rate': 0.8246914316423813}. Best is trial 5 with value: 14.460313671775216.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:49:48,047] Trial 14 finished with value: 13.992010358247372 and parameters: {'colsample_bynode': 1, 'max_depth': 8, 'subsample': 0.5319253815852273, 'n_estimators': 110, 'gamma': 8.373918243261844, 'learning_rate': 0.46211647349369894}. Best is trial 14 with value: 13.992010358247372.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:50:05,071] Trial 15 finished with value: 14.319137729746519 and parameters: {'colsample_bynode': 1, 'max_depth': 7, 'subsample': 0.5301270545056873, 'n_estimators': 38, 'gamma': 8.66592774057347, 'learning_rate': 0.40377940950312075}. Best is trial 14 with value: 13.992010358247372.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:50:16,862] Trial 16 finished with value: 14.74453108553023 and parameters: {'colsample_bynode': 1, 'max_depth': 7, 'subsample': 0.48546599688388403, 'n_estimators': 26, 'gamma': 9.284581592730666, 'learning_rate': 0.3984417394091557}. Best is trial 14 with value: 13.992010358247372.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:50:42,877] Trial 17 finished with value: 14.122457608410135 and parameters: {'colsample_bynode': 1, 'max_depth': 9, 'subsample': 0.5390580168681368, 'n_estimators': 47, 'gamma': 8.513113692509833, 'learning_rate': 0.45088407649692125}. Best is trial 14 with value: 13.992010358247372.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:51:11,478] Trial 18 finished with value: 13.708552903975171 and parameters: {'colsample_bynode': 1, 'max_depth': 9, 'subsample': 0.4293518873094265, 'n_estimators': 53, 'gamma': 11.617508249504667, 'learning_rate': 0.2581592698310395}. Best is trial 18 with value: 13.708552903975171.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:51:49,469] Trial 19 finished with value: 13.525680025460874 and parameters: {'colsample_bynode': 1, 'max_depth': 9, 'subsample': 0.4137609621865792, 'n_estimators': 69, 'gamma': 11.952033118018628, 'learning_rate': 0.2717451212681348}. Best is trial 19 with value: 13.525680025460874.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:52:28,435] Trial 20 finished with value: 13.212138474238943 and parameters: {'colsample_bynode': 1, 'max_depth': 10, 'subsample': 0.40331544930054586, 'n_estimators': 66, 'gamma': 12.335290714143028, 'learning_rate': 0.27507510257189327}. Best is trial 20 with value: 13.212138474238943.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:53:07,902] Trial 21 finished with value: 13.246625189655832 and parameters: {'colsample_bynode': 1, 'max_depth': 10, 'subsample': 0.40241556331731826, 'n_estimators': 67, 'gamma': 12.165941708120595, 'learning_rate': 0.2632523252843279}. Best is trial 20 with value: 13.212138474238943.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:53:52,663] Trial 22 finished with value: 13.160794399830241 and parameters: {'colsample_bynode': 1, 'max_depth': 10, 'subsample': 0.38475484420833, 'n_estimators': 75, 'gamma': 14.243439716298651, 'learning_rate': 0.2721260966337997}. Best is trial 22 with value: 13.160794399830241.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:54:38,092] Trial 23 finished with value: 13.196164282165553 and parameters: {'colsample_bynode': 1, 'max_depth': 10, 'subsample': 0.1990215977654382, 'n_estimators': 89, 'gamma': 18.42476865941326, 'learning_rate': 0.16158574050398727}. Best is trial 22 with value: 13.160794399830241.
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /tmp/ipykernel_7872/3202553271.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyperparameters_df = hyperparameters_df.append(
# [I 2022-11-17 11:55:21,303] Trial 24 finished with value: 13.105350974961521 and parameters: {'colsample_bynode': 1, 'max_depth': 10, 'subsample': 0.16106096384597574, 'n_estimators': 90, 'gamma': 19.64821004121042, 'learning_rate': 0.1551922513056415}. Best is trial 24 with value: 13.105350974961521.

# %%
hyperparameters_df.head()
# Out:
#    colsample_bynode  max_depth  subsample  n_estimators      gamma  \
# 0               1.0         10   0.161061            90  19.648210
# 1               1.0         10   0.384755            75  14.243440
# 2               1.0         10   0.199022            89  18.424769
# 3               1.0         10   0.403315            66  12.335291
# 4               1.0         10   0.402416            67  12.165942
#
#    learning_rate  r_squared       rmse
# 0       0.155192   0.750186  13.105351
# 1       0.272126   0.748068  13.160794
# 2       0.161586   0.746712  13.196164
# 3       0.275075   0.746098  13.212138
# 4       0.263252   0.744771  13.246625

# %%
# final model evaluation

# build and train model using the most successful hyperparameters
xgb_reg = XGBRegressor(
    colsample_bynode=hyperparameters_df.loc[0, 'colsample_bynode'],            
    max_depth=hyperparameters_df.loc[0, 'max_depth'],
    subsample=hyperparameters_df.loc[0, 'subsample'],
    n_estimators=hyperparameters_df.loc[0, 'n_estimators'],
    gamma=hyperparameters_df.loc[0, 'gamma'],
    learning_rate=hyperparameters_df.loc[0, 'learning_rate'],
)
xgb_reg.fit(X_train, y_train)

# make predictions
y_test_pred = xgb_reg.predict(X_test)

# evaluate predictions
r_squared = r2_score(y_test, y_test_pred)
rmse = mean_squared_error(y_test, y_test_pred) ** 0.5

print(f'R^2:\t{r_squared}')
print(f'RMSE:\t{rmse}')
# Out:
# /home/felix/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# R^2:	0.6132588950586824
# RMSE:	16.498942031344924
